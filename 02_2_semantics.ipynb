# %% [markdown]
# # Компьютерная семантика
#
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * https://www.nltk.org/howto/wordnet.html
# * https://ruwordnet.ru/ru
# * https://habr.com/ru/companies/unistar_digital/articles/687148/
# * https://www.scaler.com/topics/nlp/wordnet-in-nlp/

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1\. Дано описание классов `Sence` и `Synset`. Создайте объект `Synset` на основе файлов из `data/rwn`.

# %%
from dataclasses import dataclass, field

@dataclass
class Sense:
    id: str
    name: str
    lemma: str
    main_word: str
    synt_type: str
    poses: str
    synset_id: str
    meaning: str

@dataclass
class Synset:
    id: str
    ruthes_name: str
    definition: str
    part_of_speech: str
    senses: list[Sense] = field(default_factory=list)
    hyponyms: list["Synset"] = field(default_factory=list, repr=False)
    hypernyms: list["Synset"] = field(default_factory=list, repr=False)

# %%
from bs4 import BeautifulSoup

# %%
with open('sample_data/synsets.N.xml', 'r', encoding='utf8') as fp:
  syn = BeautifulSoup(fp)

# %%
example_syn = syn.find('synset')
example_syn
# Out:
# <synset definition="" id="N12658" part_of_speech="N" ruthes_name="КОДИРОВАНИЕ ОТ ЗАВИСИМОСТИ">
# <sense id="115643">МЕДИЦИНСКИЙ КОДИРОВАНИЕ</sense>
# <sense id="115640">КОДИРОВАНИЕ</sense>
# <sense id="115641">КОДИРОВАНИЕ ОТ ЗАВИСИМОСТЬ</sense>
# <sense id="115642">КОДИРОВАНИЕ ЗАВИСИМОСТЬ</sense>
# </synset>

# %%
example_syn.attrs
# Out:
# {'id': 'N12658',
#  'ruthes_name': 'КОДИРОВАНИЕ ОТ ЗАВИСИМОСТИ',
#  'definition': '',
#  'part_of_speech': 'N'}

# %%
synset = Synset(**example_syn.attrs)
synset.id
# Out:
# 'N12658'

# %%
with open('sample_data/senses.N.xml', 'r', encoding='utf8') as fp:
  senses = BeautifulSoup(fp)

# %%
senses_list = [
    Sense(**sense.attrs)
    for sense in senses.find_all('sense', synset_id=synset.id)
]
senses_list
# Out:
# [Sense(id='115643', name='МЕДИЦИНСКОЕ КОДИРОВАНИЕ', lemma='МЕДИЦИНСКИЙ КОДИРОВАНИЕ', main_word='КОДИРОВАНИЕ', synt_type='NG', poses='Adj N', synset_id='N12658', meaning='1'),
#  Sense(id='115640', name='КОДИРОВАНИЕ', lemma='КОДИРОВАНИЕ', main_word='', synt_type='N', poses='', synset_id='N12658', meaning='3'),
#  Sense(id='115641', name='КОДИРОВАНИЕ ОТ ЗАВИСИМОСТИ', lemma='КОДИРОВАНИЕ ОТ ЗАВИСИМОСТЬ', main_word='КОДИРОВАНИЕ', synt_type='NG', poses='N Prep N', synset_id='N12658', meaning='1'),
#  Sense(id='115642', name='КОДИРОВАНИЕ ЗАВИСИМОСТИ', lemma='КОДИРОВАНИЕ ЗАВИСИМОСТЬ', main_word='КОДИРОВАНИЕ', synt_type='NG', poses='N N', synset_id='N12658', meaning='1')]

# %% [markdown]
# ## Задачи для самостоятельного решения

# %%
# !pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Downloading Levenshtein-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.9/172.9 kB 2.6 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein)
#   Downloading rapidfuzz-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.22.0 rapidfuzz-3.3.1

# %%
from collections import defaultdict
from bs4 import BeautifulSoup
from Levenshtein import distance as lev
from nltk import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# <p class="task" id="1"></p>
#
# 1\. На основе файлов `rwn/synsets.A.xml`, `rwn/synsets.N.xml` и `rwn/synsets.V.xml` создайте словарь `synsets`, где ключом является ID синсета, а значением - объекта класса `Synset`. Поля `senses`, `hyponyms`, `hypernyms` оставьте со значениями по умолчанию. Выведите количество объектов в полученном словаре на экран.

# %%
synsets = {}
synset_files = ['synsets.A.xml', 'synsets.N.xml', 'synsets.V.xml']
for file in synset_files:
  with open(f'sample_data/{file}', 'r', encoding='utf8') as fp:
    synset = BeautifulSoup(fp)
    syns = synset.find_all('synset')
    for syn in syns:
      s = Synset(**syn.attrs)
      synsets[s.id] = s

# %%
len(synsets)
# Out:
# 49492

# %% [markdown]
# <p class="task" id="2"></p>
#
# 2\. Обновите поле `senses` у объектов в словаре `synsets` на основе файлов `rwn/senses.A.xml`, `rwn/senses.N.xml` и `rwn/senses.V.xml`. Выведите на экран среднее количество синонимов у синсетов.

# %%
senses_files = ['senses.A.xml', 'senses.N.xml', 'senses.V.xml']
cnt = 0
senses = []
for file in senses_files:
  with open(f'sample_data/{file}', 'r', encoding='utf8') as fp:
    senses.extend(BeautifulSoup(fp))

# %%
res = defaultdict(list)
for sen in senses:
  for s in sen.find_all('sense'):
    sense = Sense(**s.attrs)
    res[s['synset_id']].append(sense)

# %%
cnt = 0
for k, v in synsets.items():
  v.senses = res[k]
  cnt += len(res[k])

cnt / len(synsets)
# Out:
# 2.6350925402085186

# %% [markdown]
# <p class="task" id="3"></p>
#
# 3\. Проанализируйте, какие типы отношений представлены в файле `rwn/relation.xml`. Выведите множество типов отношений на экран.
# Обновите поля `hyponyms` и `hypernyms` у объектов в словаре `synsets` на основе файла `rwn/relation.xml`.

# %%
rel_files = ['synset_relations.A.xml', 'synset_relations.V.xml', 'synset_relations.N.xml']
relations = []
for file_ in rel_files:
  with open(f'sample_data/{file_}', 'r') as fp:
    relations.extend(BeautifulSoup(fp))

# %%
hypernyms = defaultdict(list)
hyponyms = defaultdict(list)
for rel in relations:
  for r in rel.find_all('relation'):
    if r['name'] == 'hypernym':
      hypernyms[r['parent_id']].append(synsets[r['child_id']])
    elif r['name'] == 'hyponym':
      hyponyms[r['parent_id']].append(synsets[r['child_id']])

# %%
for k, v in synsets.items():
  v.hypernyms = hypernyms[k]
  v.hyponyms = hyponyms[k]

# %% [markdown]
# <p class="task" id="4"></p>
#
# 4\. Напишите функцию `find_by_name`, которая ищет синсеты по вхождению заданного слова в поле `ruthes_name`. При поиске приводите введенное слово к нормальной форме и не учитывайте регистр слов. Функция должна вернуть список, отсортированный по возрастаю значений расстояния Левенштейна между названием синсета и введенным словом. Продемонстрируйте, какие синсеты находятся по слову "собака".

# %%
# !pip install pymorphy2

# %%
from pymorphy2 import MorphAnalyzer

# %%
def find_by_name(word, syns):
  res = []
  morph = MorphAnalyzer()
  word = morph.parse(word)[0].normal_form
  for k, v in syns.items():
    if word in v.ruthes_name.lower():
      res.append((syns[k], lev(word.lower(), v.ruthes_name.lower())))
  res = sorted(res, key=lambda x: x[1])
  return list(map(lambda x: x[0], res))

# %%
find_by_name('собака', synsets)
# Out:
# [Synset(id='A6565', ruthes_name='СОБАКА', definition='хищное млекопитающее семейства псовых', part_of_speech='Adj', senses=[Sense(id='4612', name='ПСИНЫЙ', lemma='ПСИНЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A6565', meaning='1'), Sense(id='4946', name='ПЕСИЙ', lemma='ПЕСИЙ', main_word='', synt_type='Adj', poses='', synset_id='A6565', meaning='1'), Sense(id='5115', name='СОБАЧИЙ', lemma='СОБАЧИЙ', main_word='', synt_type='Adj', poses='', synset_id='A6565', meaning='1')]),
#  Synset(id='N18450', ruthes_name='СОБАКА', definition='хищное млекопитающее семейства псовых', part_of_speech='N', senses=[Sense(id='5046', name='ПЕСИК', lemma='ПЕСИК', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='1'), Sense(id='5113', name='ПЕС', lemma='ПЕС', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='2'), Sense(id='5114', name='СОБАКА', lemma='СОБАКА', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='1'), Sense(id='5116', name='СОБАЧКА', lemma='СОБАЧКА', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='2'), Sense(id='5117', name='СОБАЧОНКА', lemma='СОБАЧОНКА', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='1'), Sense(id='5118', name='ЧЕТВЕРОНОГИЙ ДРУГ', lemma='ЧЕТВЕРОНОГИЙ ДРУГ', main_word='ДРУГ', synt_type='NG', poses='Adj N', synset_id='N18450', meaning='1'), Sense(id='4467', name='ПСИНА', lemma='ПСИНА', main_word='', synt_type='N', poses='', synset_id='N18450', meaning='1')]),
#  Synset(id='A966', ruthes_name='БОРЗАЯ СОБАКА', definition='', part_of_speech='Adj', senses=[Sense(id='43330', name='БОРЗОЙ', lemma='БОРЗОЙ', main_word='', synt_type='Adj', poses='', synset_id='A966', meaning='1')]),
#  Synset(id='N32046', ruthes_name='БОРЗАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='43331', name='БОРЗАЯ СОБАКА', lemma='БОРЗОЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N32046', meaning='1'), Sense(id='43329', name='БОРЗАЯ', lemma='БОРЗАЯ', main_word='', synt_type='N', poses='', synset_id='N32046', meaning='1')]),
#  Synset(id='A1914', ruthes_name='ЩЕНОК (СОБАКА)', definition='', part_of_speech='Adj', senses=[Sense(id='34017', name='ЩЕНЯЧИЙ', lemma='ЩЕНЯЧИЙ', main_word='', synt_type='Adj', poses='', synset_id='A1914', meaning='1')]),
#  Synset(id='A3626', ruthes_name='ЛЕГАВАЯ СОБАКА', definition='', part_of_speech='Adj', senses=[Sense(id='72435', name='ЛЕГАВЫЙ', lemma='ЛЕГАВЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A3626', meaning='1')]),
#  Synset(id='A11469', ruthes_name='ЛАЙКА (СОБАКА)', definition='', part_of_speech='Adj', senses=[Sense(id='26482', name='ЛАЕЧНЫЙ', lemma='ЛАЕЧНЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A11469', meaning='1')]),
#  Synset(id='N18021', ruthes_name='ЩЕНОК (СОБАКА)', definition='', part_of_speech='N', senses=[Sense(id='34013', name='ЦУЦИК', lemma='ЦУЦИК', main_word='', synt_type='N', poses='', synset_id='N18021', meaning='1'), Sense(id='34014', name='ЩЕНОК', lemma='ЩЕНОК', main_word='', synt_type='N', poses='', synset_id='N18021', meaning='2'), Sense(id='34015', name='КУТЕНОК', lemma='КУТЕНОК', main_word='', synt_type='N', poses='', synset_id='N18021', meaning='1'), Sense(id='34016', name='ЩЕНОЧЕК', lemma='ЩЕНОЧЕК', main_word='', synt_type='N', poses='', synset_id='N18021', meaning='1')]),
#  Synset(id='N27501', ruthes_name='ЛЕГАВАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='72436', name='ЛЕГАВАЯ СОБАКА', lemma='ЛЕГАВЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N27501', meaning='1'), Sense(id='72434', name='ЛЕГАВАЯ', lemma='ЛЕГАВАЯ', main_word='', synt_type='N', poses='', synset_id='N27501', meaning='1')]),
#  Synset(id='N30243', ruthes_name='ЛАЙКА (СОБАКА)', definition='', part_of_speech='N', senses=[Sense(id='26481', name='ЛАЙКА', lemma='ЛАЙКА', main_word='', synt_type='N', poses='', synset_id='N30243', meaning='2')]),
#  Synset(id='N35039', ruthes_name='ТАКСА (СОБАКА)', definition='порода небольших собак с короткими ногами и длинным туловищем', part_of_speech='N', senses=[Sense(id='32529', name='ТАКСА', lemma='ТАКСА', main_word='', synt_type='N', poses='', synset_id='N35039', meaning='2')]),
#  Synset(id='A333', ruthes_name='БОКСЕР (СОБАКА)', definition='', part_of_speech='Adj', senses=[Sense(id='43291', name='БОКСЕРСКИЙ', lemma='БОКСЕРСКИЙ', main_word='', synt_type='Adj', poses='', synset_id='A333', meaning='3')]),
#  Synset(id='A9227', ruthes_name='КОБЕЛЬ (СОБАКА)', definition='', part_of_speech='Adj', senses=[Sense(id='5112', name='КОБЕЛИНЫЙ', lemma='КОБЕЛИНЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A9227', meaning='1')]),
#  Synset(id='N30406', ruthes_name='КОБЕЛЬ (СОБАКА)', definition='', part_of_speech='N', senses=[Sense(id='5110', name='ПЕС', lemma='ПЕС', main_word='', synt_type='N', poses='', synset_id='N30406', meaning='3'), Sense(id='5111', name='КОБЕЛЬ', lemma='КОБЕЛЬ', main_word='', synt_type='N', poses='', synset_id='N30406', meaning='1')]),
#  Synset(id='N37588', ruthes_name='БОКСЕР (СОБАКА)', definition='', part_of_speech='N', senses=[Sense(id='43289', name='БОКСЕР', lemma='БОКСЕР', main_word='', synt_type='N', poses='', synset_id='N37588', meaning='3'), Sense(id='43290', name='СОБАКА ПОРОДЫ БОКСЕР', lemma='СОБАКА ПОРОДА БОКСЕР', main_word='СОБАКА', synt_type='NG', poses='N N N', synset_id='N37588', meaning='1')]),
#  Synset(id='N18180', ruthes_name='КОМНАТНАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='112373', name='ДЕКОРАТИВНАЯ СОБАКА', lemma='ДЕКОРАТИВНЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N18180', meaning='1'), Sense(id='112371', name='КОМНАТНАЯ СОБАКА', lemma='КОМНАТНЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N18180', meaning='1'), Sense(id='112372', name='КОМНАТНАЯ СОБАЧКА', lemma='КОМНАТНЫЙ СОБАЧКА', main_word='СОБАЧКА', synt_type='NG', poses='Adj N', synset_id='N18180', meaning='1'), Sense(id='112374', name='ДЕКОРАТИВНАЯ СОБАЧКА', lemma='ДЕКОРАТИВНЫЙ СОБАЧКА', main_word='СОБАЧКА', synt_type='NG', poses='Adj N', synset_id='N18180', meaning='1')]),
#  Synset(id='N27920', ruthes_name='ОХОТНИЧЬЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='111707', name='ОХОТНИЧЬЯ СОБАКА', lemma='ОХОТНИЧИЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N27920', meaning='1'), Sense(id='111706', name='ОХОТНИЧИЙ ПЕС', lemma='ОХОТНИЧИЙ ПЕС', main_word='ПЕС', synt_type='NG', poses='Adj N', synset_id='N27920', meaning='1')]),
#  Synset(id='N31025', ruthes_name='СЛУЖЕБНАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='112499', name='СЛУЖЕБНАЯ СОБАКА', lemma='СЛУЖЕБНЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N31025', meaning='1')]),
#  Synset(id='N39607', ruthes_name='ПОИСКОВАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='47290', name='СЛУЖЕБНО-РОЗЫСКНАЯ СОБАКА', lemma='СЛУЖЕБНО-РОЗЫСКНОЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N39607', meaning='1'), Sense(id='47291', name='ПОИСКОВАЯ СОБАКА', lemma='ПОИСКОВЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N39607', meaning='1'), Sense(id='47292', name='РОЗЫСКНАЯ СОБАКА', lemma='РОЗЫСКНОЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N39607', meaning='1'), Sense(id='47288', name='ИЩЕЙКА', lemma='ИЩЕЙКА', main_word='', synt_type='N', poses='', synset_id='N39607', meaning='2'), Sense(id='47289', name='СОБАКА-ИЩЕЙКА', lemma='СОБАКА ИЩЕЙКА', main_word='', synt_type='N', poses='', synset_id='N39607', meaning='1')]),
#  Synset(id='A2842', ruthes_name='ЕНОТОВИДНАЯ СОБАКА', definition='', part_of_speech='Adj', senses=[Sense(id='121295', name='ЕНОТОВИДНЫЙ', lemma='ЕНОТОВИДНЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A2842', meaning='1')]),
#  Synset(id='N30982', ruthes_name='ЕНОТОВИДНАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='121296', name='ЕНОТОВИДНАЯ СОБАКА', lemma='ЕНОТОВИДНЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N30982', meaning='1')]),
#  Synset(id='N35590', ruthes_name='БЕСПОРОДНАЯ СОБАКА', definition='', part_of_speech='N', senses=[Sense(id='21773', name='БОБИК', lemma='БОБИК', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21774', name='ТУЗИК', lemma='ТУЗИК', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21775', name='ШАВКА', lemma='ШАВКА', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21776', name='БАРБОС', lemma='БАРБОС', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21777', name='ДВОРНЯГА', lemma='ДВОРНЯГА', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21778', name='ДВОРОВАЯ СОБАКА', lemma='ДВОРОВЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N35590', meaning='1'), Sense(id='21779', name='ДВОРНЯЖКА', lemma='ДВОРНЯЖКА', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21780', name='ДВОРТЕРЬЕР', lemma='ДВОРТЕРЬЕР', main_word='', synt_type='N', poses='', synset_id='N35590', meaning='1'), Sense(id='21781', name='БЕСПОРОДНАЯ СОБАКА', lemma='БЕСПОРОДНЫЙ СОБАКА', main_word='СОБАКА', synt_type='NG', poses='Adj N', synset_id='N35590', meaning='1')])]

# %% [markdown]
# <p class="task" id="5"></p>
#
# 5\. Для пары слов "собака" и "кошка" найдите ближайший общий родительский синсет и выведите на экран его название. Синсет `A` назовем родительским синсетом синсета `B`, если от `B` можно подняться к `A` в таксономии синсетов, используя отношения гиперонимии. Найдите общий родительский синсет для пары слов "кошка" и "студент" и выведите на экран его название.

# %%
dog = find_by_name('собака', synsets)
cat = find_by_name('кошка', synsets)

# %%
def parse_hypernyms(hypernyms1, hypernyms2):
    for hyp1 in hypernyms1:
      for hyp2 in hypernyms2:
        if hyp1 == hyp2:
          return hyp1
    return parse_hypernyms(hypernyms1[0].hypernyms, hypernyms1[0].hypernyms)

# %%
parse_hypernyms(dog[0].hypernyms, cat[0].hypernyms)
# Out:
# Synset(id='A957', ruthes_name='ПОЗВОНОЧНОЕ ЖИВОТНОЕ', definition='', part_of_speech='Adj', senses=[Sense(id='122640', name='ПОЗВОНОЧНЫЕ', lemma='ПОЗВОНОЧНЫЙ', main_word='', synt_type='Adj', poses='', synset_id='A957', meaning='1')])

# %%
student = find_by_name('студент', synsets)

# %%
len(cat)
# Out:
# 2

# %%
parse_hypernyms(cat[0].hypernyms, student[0].hypernyms)
# Out:
# Synset(id='A2250', ruthes_name='ЖИВОЙ ОРГАНИЗМ', definition='живое существо, как правило, низкоорганизованное', part_of_speech='Adj', senses=[Sense(id='24451', name='БИОЛОГИЧЕСКИЙ', lemma='БИОЛОГИЧЕСКИЙ', main_word='', synt_type='Adj', poses='', synset_id='A2250', meaning='3')])

# %% [markdown]
# <p class="task" id="6"></p>
#
# 6\. Для каждого слова из представленного текста найдите все возможные синонимы. Набор синонимов получите на основе поля `senses` у объектов `Synset`. В случае обнаружения точного совпадения введенного слова хотя бы с одним элементом из `senses`, весь набор `senses` трактуйте как синонимы. При поиске приводите слово к нормальной форме и не учитывайте регистр слов.
#
# Составьте все возможные вариации данного предложения, заменяя слова на найденные синонимы. В случае отсутствия синонимов для какого-то из слов, используйте исходное слово для генерации предложения. Выведите на экран общее количество перефразированных предложений.

# %%
text = "Студент ужаснулся когда увидел задачу"

# %%
res = {}
morph = MorphAnalyzer()
for word in word_tokenize(text.lower()):
  res[morph.parse(word)[0].normal_form] = [sen.senses for sen in find_by_name(word, synsets)]

# %%
for k, v in res.items():
  names = []
  for lst in v:
    names.extend(list(map(lambda x: x.name.lower(), lst)))
  if k in names:
    res[k] = names
  else:
    res[k] = [k]
res
# Out:
# {'студент': ['студент',
#   'студентка',
#   'слушательский',
#   'слушатель курсов',
#   'слушательница',
#   'слушательница курсов',
#   'слушатель факультета',
#   'слушатель'],
#  'ужаснуться': ['леденящий ужас',
#   'кровь стынет в жилах',
#   'кровь леденеет в жилах',
#   'кровь холодеет в жилах',
#   'стынет кровь',
#   'стынет кровь в жилах',
#   'ужасаться',
#   'приходить в ужас',
#   'прийти в ужас',
#   'ужаснуться',
#   'приходить в ужас',
#   'схватиться за голову',
#   'ужаснуться',
#   'прийти в ужас',
#   'ужасаться',
#   'хвататься за голову',
#   'неприятно удивиться'],
#  'когда': ['когда'],
#  'увидеть': ['встреча',
#   'иметь встречу',
#   'видеть',
#   'увидеть',
#   'видаться',
#   'видеться',
#   'повидать',
#   'встретить',
#   'встречать',
#   'свидеться',
#   'увидеться',
#   'пересечься',
#   'встретиться',
#   'встречаться',
#   'пересекаться',
#   'повидаться',
#   'увидеть издали',
#   'завидеть издали',
#   'завидеть',
#   'показ',
#   'показывание',
#   'показать',
#   'показывать'],
#  'задача': ['задачный',
#   'задача',
#   'максимальная задача',
#   'сверхзадача',
#   'задачный',
#   'задачка',
#   'задача',
#   'головоломка',
#   'кроссвордный',
#   'кроссворд']}

# %%
import itertools

result_sents = []
for el in itertools.product(*res.values()):
    result_sents.append(' '.join(el))
print(f'Количество полученных предложений: {len(result_sents)}')
# Out:
# Количество полученных предложений: 31280

# %%
result_sents[::1000]
# Out:
# ['студент леденящий ужас когда встреча задачный',
#  'студент стынет кровь когда встречать задачный',
#  'студент прийти в ужас когда увидеть издали задачный',
#  'студент прийти в ужас когда иметь встречу задачный',
#  'студентка леденящий ужас когда свидеться задачный',
#  'студентка стынет кровь когда завидеть издали задачный',
#  'студентка ужаснуться когда видеть задачный',
#  'студентка прийти в ужас когда увидеться задачный',
#  'слушательский леденящий ужас когда завидеть задачный',
#  'слушательский стынет кровь в жилах когда увидеть задачный',
#  'слушательский ужаснуться когда пересечься задачный',
#  'слушательский прийти в ужас когда показ задачный',
#  'слушатель курсов кровь стынет в жилах когда видаться задачный',
#  'слушатель курсов стынет кровь в жилах когда встретиться задачный',
#  'слушатель курсов ужаснуться когда показывание задачный',
#  'слушатель курсов ужасаться когда видеться задачный',
#  'слушательница кровь стынет в жилах когда встречаться задачный',
#  'слушательница стынет кровь в жилах когда показать задачный',
#  'слушательница приходить в ужас когда повидать задачный',
#  'слушательница ужасаться когда пересекаться задачный',
#  'слушательница курсов кровь стынет в жилах когда показывать задачный',
#  'слушательница курсов ужасаться когда встретить задачный',
#  'слушательница курсов приходить в ужас когда повидаться задачный',
#  'слушательница курсов хвататься за голову когда встреча задачный',
#  'слушатель факультета кровь леденеет в жилах когда встречать задачный',
#  'слушатель факультета ужасаться когда увидеть издали задачный',
#  'слушатель факультета схватиться за голову когда иметь встречу задачный',
#  'слушатель факультета хвататься за голову когда свидеться задачный',
#  'слушатель кровь леденеет в жилах когда завидеть издали задачный',
#  'слушатель приходить в ужас когда видеть задачный',
#  'слушатель схватиться за голову когда увидеться задачный',
#  'слушатель хвататься за голову когда завидеть задачный']

# %% [markdown]
# ## Обратная связь
# - [x] Хочу получить обратную связь по решению
